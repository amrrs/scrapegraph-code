# %%
# !pip3 install scrapegraphai==0.9.0b7 --upgrade
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scrapegraphai==0.9.0b7
#   Downloading scrapegraphai-0.9.0b7-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: beautifulsoup4==4.12.3 in ./Library/Python/3.9/lib/python/site-packages (from scrapegraphai==0.9.0b7) (4.12.3)
# Requirement already satisfied: faiss-cpu==1.8.0 in ./Library/Python/3.9/lib/python/site-packages (from scrapegraphai==0.9.0b7) (1.8.0)
# Requirement already satisfied: free-proxy==1.1.1 in ./Library/Python/3.9/lib/python/site-packages (from scrapegraphai==0.9.0b7) (1.1.1)
# Requirement already satisfied: google==3.0.0 in ./Library/Python/3.9/lib/python/site-packages (from scrapegraphai==0.9.0b7) (3.0.0)
# Collecting graphviz==0.20.1 (from scrapegraphai==0.9.0b7)
#   Downloading graphviz-0.20.1-py3-none-any.whl.metadata (12 kB)
# Collecting html2text==2020.1.16 (from scrapegraphai==0.9.0b7)
#   Downloading html2text-2020.1.16-py3-none-any.whl.metadata (4.3 kB)
# Collecting langchain==0.1.14 (from scrapegraphai==0.9.0b7)
#   Downloading langchain-0.1.14-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: langchain-anthropic<0.2.0,>=0.1.11 in ./Library/Python/3.9/lib/python/site-packages (from scrapegraphai==0.9.0b7) (0.1.11)
# Requirement already satisfied: langchain-aws<0.2.0,>=0.1.2 in ./Library/Python/3.9/lib/python/site-packages (from scrapegraphai==0.9.0b7) (0.1.3)
# Collecting langchain-google-genai==1.0.1 (from scrapegraphai==0.9.0b7)
#   Downloading langchain_google_genai-1.0.1-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: langchain-groq==0.1.3 in ./Library/Python/3.9/lib/python/site-packages (from scrapegraphai==0.9.0b7) (0.1.3)
# Collecting langchain-openai==0.1.1 (from scrapegraphai==0.9.0b7)
#   Downloading langchain_openai-0.1.1-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: minify-html==0.15.0 in ./Library/Python/3.9/lib/python/site-packages (from scrapegraphai==0.9.0b7) (0.15.0)
# Collecting pandas==2.0.3 (from scrapegraphai==0.9.0b7)
#   Downloading pandas-2.0.3-cp39-cp39-macosx_11_0_arm64.whl.metadata (18 kB)
# Requirement already satisfied: playwright<2.0.0,>=1.43.0 in ./Library/Python/3.9/lib/python/site-packages (from scrapegraphai==0.9.0b7) (1.43.0)
# Requirement already satisfied: python-dotenv==1.0.1 in ./Library/Python/3.9/lib/python/site-packages (from scrapegraphai==0.9.0b7) (1.0.1)
# Collecting tiktoken<0.6.0,>=0.5.2 (from scrapegraphai==0.9.0b7)
#   Downloading tiktoken-0.5.2-cp39-cp39-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting tqdm==4.66.3 (from scrapegraphai==0.9.0b7)
#   Downloading tqdm-4.66.3-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 922.1 kB/s eta 0:00:00MB/s eta 0:00:01
# Requirement already satisfied: yahoo-search-py<0.4,>=0.3 in ./Library/Python/3.9/lib/python/site-packages (from scrapegraphai==0.9.0b7) (0.3)
# Requirement already satisfied: soupsieve>1.2 in ./Library/Python/3.9/lib/python/site-packages (from beautifulsoup4==4.12.3->scrapegraphai==0.9.0b7) (2.5)
# Requirement already satisfied: numpy in ./Library/Python/3.9/lib/python/site-packages (from faiss-cpu==1.8.0->scrapegraphai==0.9.0b7) (1.26.3)
# Requirement already satisfied: lxml in ./Library/Python/3.9/lib/python/site-packages (from free-proxy==1.1.1->scrapegraphai==0.9.0b7) (4.9.4)
# Requirement already satisfied: requests in ./Library/Python/3.9/lib/python/site-packages (from free-proxy==1.1.1->scrapegraphai==0.9.0b7) (2.31.0)
# Requirement already satisfied: PyYAML>=5.3 in ./Library/Python/3.9/lib/python/site-packages (from langchain==0.1.14->scrapegraphai==0.9.0b7) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in ./Library/Python/3.9/lib/python/site-packages (from langchain==0.1.14->scrapegraphai==0.9.0b7) (2.0.25)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in ./Library/Python/3.9/lib/python/site-packages (from langchain==0.1.14->scrapegraphai==0.9.0b7) (3.9.3)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in ./Library/Python/3.9/lib/python/site-packages (from langchain==0.1.14->scrapegraphai==0.9.0b7) (4.0.3)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in ./Library/Python/3.9/lib/python/site-packages (from langchain==0.1.14->scrapegraphai==0.9.0b7) (0.6.4)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./Library/Python/3.9/lib/python/site-packages (from langchain==0.1.14->scrapegraphai==0.9.0b7) (1.33)
# Requirement already satisfied: langchain-community<0.1,>=0.0.30 in ./Library/Python/3.9/lib/python/site-packages (from langchain==0.1.14->scrapegraphai==0.9.0b7) (0.0.38)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.37 in ./Library/Python/3.9/lib/python/site-packages (from langchain==0.1.14->scrapegraphai==0.9.0b7) (0.1.52)
# Requirement already satisfied: langchain-text-splitters<0.1,>=0.0.1 in ./Library/Python/3.9/lib/python/site-packages (from langchain==0.1.14->scrapegraphai==0.9.0b7) (0.0.1)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in ./Library/Python/3.9/lib/python/site-packages (from langchain==0.1.14->scrapegraphai==0.9.0b7) (0.1.56)
# Requirement already satisfied: pydantic<3,>=1 in ./Library/Python/3.9/lib/python/site-packages (from langchain==0.1.14->scrapegraphai==0.9.0b7) (2.6.2)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in ./Library/Python/3.9/lib/python/site-packages (from langchain==0.1.14->scrapegraphai==0.9.0b7) (8.2.3)
# Collecting google-generativeai<0.5.0,>=0.4.1 (from langchain-google-genai==1.0.1->scrapegraphai==0.9.0b7)
#   Downloading google_generativeai-0.4.1-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: groq<1,>=0.4.1 in ./Library/Python/3.9/lib/python/site-packages (from langchain-groq==0.1.3->scrapegraphai==0.9.0b7) (0.5.0)
# Requirement already satisfied: openai<2.0.0,>=1.10.0 in ./Library/Python/3.9/lib/python/site-packages (from langchain-openai==0.1.1->scrapegraphai==0.9.0b7) (1.27.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./Library/Python/3.9/lib/python/site-packages (from pandas==2.0.3->scrapegraphai==0.9.0b7) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./Library/Python/3.9/lib/python/site-packages (from pandas==2.0.3->scrapegraphai==0.9.0b7) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in ./Library/Python/3.9/lib/python/site-packages (from pandas==2.0.3->scrapegraphai==0.9.0b7) (2023.4)
# Requirement already satisfied: anthropic<1,>=0.23.0 in ./Library/Python/3.9/lib/python/site-packages (from langchain-anthropic<0.2.0,>=0.1.11->scrapegraphai==0.9.0b7) (0.25.8)
# Requirement already satisfied: defusedxml<0.8.0,>=0.7.1 in ./Library/Python/3.9/lib/python/site-packages (from langchain-anthropic<0.2.0,>=0.1.11->scrapegraphai==0.9.0b7) (0.7.1)
# Requirement already satisfied: boto3<1.35.0,>=1.34.51 in ./Library/Python/3.9/lib/python/site-packages (from langchain-aws<0.2.0,>=0.1.2->scrapegraphai==0.9.0b7) (1.34.101)
# Requirement already satisfied: greenlet==3.0.3 in ./Library/Python/3.9/lib/python/site-packages (from playwright<2.0.0,>=1.43.0->scrapegraphai==0.9.0b7) (3.0.3)
# Requirement already satisfied: pyee==11.1.0 in ./Library/Python/3.9/lib/python/site-packages (from playwright<2.0.0,>=1.43.0->scrapegraphai==0.9.0b7) (11.1.0)
# Requirement already satisfied: typing-extensions in ./Library/Python/3.9/lib/python/site-packages (from pyee==11.1.0->playwright<2.0.0,>=1.43.0->scrapegraphai==0.9.0b7) (4.9.0)
# Requirement already satisfied: regex>=2022.1.18 in ./Library/Python/3.9/lib/python/site-packages (from tiktoken<0.6.0,>=0.5.2->scrapegraphai==0.9.0b7) (2023.12.25)
# Requirement already satisfied: httpx in ./Library/Python/3.9/lib/python/site-packages (from yahoo-search-py<0.4,>=0.3->scrapegraphai==0.9.0b7) (0.25.2)
# Requirement already satisfied: selectolax in ./Library/Python/3.9/lib/python/site-packages (from yahoo-search-py<0.4,>=0.3->scrapegraphai==0.9.0b7) (0.3.21)
# Requirement already satisfied: urllib3 in ./Library/Python/3.9/lib/python/site-packages (from yahoo-search-py<0.4,>=0.3->scrapegraphai==0.9.0b7) (1.26.18)
# Requirement already satisfied: aiosignal>=1.1.2 in ./Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.14->scrapegraphai==0.9.0b7) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in ./Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.14->scrapegraphai==0.9.0b7) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.14->scrapegraphai==0.9.0b7) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.14->scrapegraphai==0.9.0b7) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.1.14->scrapegraphai==0.9.0b7) (1.9.4)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./Library/Python/3.9/lib/python/site-packages (from anthropic<1,>=0.23.0->langchain-anthropic<0.2.0,>=0.1.11->scrapegraphai==0.9.0b7) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in ./Library/Python/3.9/lib/python/site-packages (from anthropic<1,>=0.23.0->langchain-anthropic<0.2.0,>=0.1.11->scrapegraphai==0.9.0b7) (1.9.0)
# Requirement already satisfied: sniffio in ./Library/Python/3.9/lib/python/site-packages (from anthropic<1,>=0.23.0->langchain-anthropic<0.2.0,>=0.1.11->scrapegraphai==0.9.0b7) (1.3.0)
# Requirement already satisfied: tokenizers>=0.13.0 in ./Library/Python/3.9/lib/python/site-packages (from anthropic<1,>=0.23.0->langchain-anthropic<0.2.0,>=0.1.11->scrapegraphai==0.9.0b7) (0.15.1)
# Requirement already satisfied: botocore<1.35.0,>=1.34.101 in ./Library/Python/3.9/lib/python/site-packages (from boto3<1.35.0,>=1.34.51->langchain-aws<0.2.0,>=0.1.2->scrapegraphai==0.9.0b7) (1.34.101)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in ./Library/Python/3.9/lib/python/site-packages (from boto3<1.35.0,>=1.34.51->langchain-aws<0.2.0,>=0.1.2->scrapegraphai==0.9.0b7) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in ./Library/Python/3.9/lib/python/site-packages (from boto3<1.35.0,>=1.34.51->langchain-aws<0.2.0,>=0.1.2->scrapegraphai==0.9.0b7) (0.10.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in ./Library/Python/3.9/lib/python/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.14->scrapegraphai==0.9.0b7) (3.20.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in ./Library/Python/3.9/lib/python/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain==0.1.14->scrapegraphai==0.9.0b7) (0.9.0)
# Collecting google-ai-generativelanguage==0.4.0 (from google-generativeai<0.5.0,>=0.4.1->langchain-google-genai==1.0.1->scrapegraphai==0.9.0b7)
#   Downloading google_ai_generativelanguage-0.4.0-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: google-auth>=2.15.0 in ./Library/Python/3.9/lib/python/site-packages (from google-generativeai<0.5.0,>=0.4.1->langchain-google-genai==1.0.1->scrapegraphai==0.9.0b7) (2.27.0)
# Requirement already satisfied: google-api-core in ./Library/Python/3.9/lib/python/site-packages (from google-generativeai<0.5.0,>=0.4.1->langchain-google-genai==1.0.1->scrapegraphai==0.9.0b7) (2.19.0)
# Requirement already satisfied: protobuf in ./Library/Python/3.9/lib/python/site-packages (from google-generativeai<0.5.0,>=0.4.1->langchain-google-genai==1.0.1->scrapegraphai==0.9.0b7) (4.25.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in ./Library/Python/3.9/lib/python/site-packages (from google-ai-generativelanguage==0.4.0->google-generativeai<0.5.0,>=0.4.1->langchain-google-genai==1.0.1->scrapegraphai==0.9.0b7) (1.23.0)
# Requirement already satisfied: certifi in ./Library/Python/3.9/lib/python/site-packages (from httpx->yahoo-search-py<0.4,>=0.3->scrapegraphai==0.9.0b7) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in ./Library/Python/3.9/lib/python/site-packages (from httpx->yahoo-search-py<0.4,>=0.3->scrapegraphai==0.9.0b7) (1.0.2)
# Requirement already satisfied: idna in ./Library/Python/3.9/lib/python/site-packages (from httpx->yahoo-search-py<0.4,>=0.3->scrapegraphai==0.9.0b7) (3.6)
# Requirement already satisfied: h11<0.15,>=0.13 in ./Library/Python/3.9/lib/python/site-packages (from httpcore==1.*->httpx->yahoo-search-py<0.4,>=0.3->scrapegraphai==0.9.0b7) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./Library/Python/3.9/lib/python/site-packages (from jsonpatch<2.0,>=1.33->langchain==0.1.14->scrapegraphai==0.9.0b7) (2.4)
# Requirement already satisfied: packaging<24.0,>=23.2 in ./Library/Python/3.9/lib/python/site-packages (from langchain-core<0.2.0,>=0.1.37->langchain==0.1.14->scrapegraphai==0.9.0b7) (23.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in ./Library/Python/3.9/lib/python/site-packages (from langsmith<0.2.0,>=0.1.17->langchain==0.1.14->scrapegraphai==0.9.0b7) (3.9.15)
# Requirement already satisfied: annotated-types>=0.4.0 in ./Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1->langchain==0.1.14->scrapegraphai==0.9.0b7) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in ./Library/Python/3.9/lib/python/site-packages (from pydantic<3,>=1->langchain==0.1.14->scrapegraphai==0.9.0b7) (2.16.3)
# Requirement already satisfied: six>=1.5 in ./Library/Python/3.9/lib/python/site-packages (from python-dateutil>=2.8.2->pandas==2.0.3->scrapegraphai==0.9.0b7) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./Library/Python/3.9/lib/python/site-packages (from requests->free-proxy==1.1.1->scrapegraphai==0.9.0b7) (3.3.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./Library/Python/3.9/lib/python/site-packages (from anyio<5,>=3.5.0->anthropic<1,>=0.23.0->langchain-anthropic<0.2.0,>=0.1.11->scrapegraphai==0.9.0b7) (1.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in ./Library/Python/3.9/lib/python/site-packages (from google-api-core->google-generativeai<0.5.0,>=0.4.1->langchain-google-genai==1.0.1->scrapegraphai==0.9.0b7) (1.62.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./Library/Python/3.9/lib/python/site-packages (from google-auth>=2.15.0->google-generativeai<0.5.0,>=0.4.1->langchain-google-genai==1.0.1->scrapegraphai==0.9.0b7) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./Library/Python/3.9/lib/python/site-packages (from google-auth>=2.15.0->google-generativeai<0.5.0,>=0.4.1->langchain-google-genai==1.0.1->scrapegraphai==0.9.0b7) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./Library/Python/3.9/lib/python/site-packages (from google-auth>=2.15.0->google-generativeai<0.5.0,>=0.4.1->langchain-google-genai==1.0.1->scrapegraphai==0.9.0b7) (4.9)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in ./Library/Python/3.9/lib/python/site-packages (from tokenizers>=0.13.0->anthropic<1,>=0.23.0->langchain-anthropic<0.2.0,>=0.1.11->scrapegraphai==0.9.0b7) (0.20.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./Library/Python/3.9/lib/python/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain==0.1.14->scrapegraphai==0.9.0b7) (1.0.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in ./Library/Python/3.9/lib/python/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-ai-generativelanguage==0.4.0->google-generativeai<0.5.0,>=0.4.1->langchain-google-genai==1.0.1->scrapegraphai==0.9.0b7) (1.63.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in ./Library/Python/3.9/lib/python/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-ai-generativelanguage==0.4.0->google-generativeai<0.5.0,>=0.4.1->langchain-google-genai==1.0.1->scrapegraphai==0.9.0b7) (1.62.2)
# Requirement already satisfied: filelock in ./Library/Python/3.9/lib/python/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic<1,>=0.23.0->langchain-anthropic<0.2.0,>=0.1.11->scrapegraphai==0.9.0b7) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in ./Library/Python/3.9/lib/python/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.0->anthropic<1,>=0.23.0->langchain-anthropic<0.2.0,>=0.1.11->scrapegraphai==0.9.0b7) (2023.12.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in ./Library/Python/3.9/lib/python/site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai<0.5.0,>=0.4.1->langchain-google-genai==1.0.1->scrapegraphai==0.9.0b7) (0.5.1)
# Downloading scrapegraphai-0.9.0b7-py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 3.5 MB/s eta 0:00:00
# Downloading graphviz-0.20.1-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.0/47.0 kB 4.1 MB/s eta 0:00:00
# Downloading html2text-2020.1.16-py3-none-any.whl (32 kB)
# Downloading langchain-0.1.14-py3-none-any.whl (812 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 812.8/812.8 kB 6.6 MB/s eta 0:00:006.8 MB/s eta 0:00:01
# Downloading langchain_google_genai-1.0.1-py3-none-any.whl (28 kB)
# Downloading langchain_openai-0.1.1-py3-none-any.whl (32 kB)
# Downloading pandas-2.0.3-cp39-cp39-macosx_11_0_arm64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 24.2 MB/s eta 0:00:000:00:0136m0:00:01:01
# Downloading tqdm-4.66.3-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 8.6 MB/s eta 0:00:00
# Downloading tiktoken-0.5.2-cp39-cp39-macosx_11_0_arm64.whl (955 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 955.6/955.6 kB 22.7 MB/s eta 0:00:00m eta 0:00:01
# Downloading google_generativeai-0.4.1-py3-none-any.whl (137 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.4/137.4 kB 11.6 MB/s eta 0:00:00
# Downloading google_ai_generativelanguage-0.4.0-py3-none-any.whl (598 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 598.7/598.7 kB 9.3 MB/s eta 0:00:009 MB/s eta 0:00:01
# Installing collected packages: tqdm, html2text, graphviz, tiktoken, pandas, langchain-openai, google-ai-generativelanguage, langchain, google-generativeai, langchain-google-genai, scrapegraphai
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.66.4
#     Uninstalling tqdm-4.66.4:
#       Successfully uninstalled tqdm-4.66.4
#   Attempting uninstall: html2text
#     Found existing installation: html2text 2024.2.26
#     Uninstalling html2text-2024.2.26:
#       Successfully uninstalled html2text-2024.2.26
#   Attempting uninstall: graphviz
#     Found existing installation: graphviz 0.20.3
#     Uninstalling graphviz-0.20.3:
#       Successfully uninstalled graphviz-0.20.3
#   Attempting uninstall: tiktoken
#     Found existing installation: tiktoken 0.6.0
#     Uninstalling tiktoken-0.6.0:
#       Successfully uninstalled tiktoken-0.6.0
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: langchain-openai
#     Found existing installation: langchain-openai 0.1.6
#     Uninstalling langchain-openai-0.1.6:
#       Successfully uninstalled langchain-openai-0.1.6
#   Attempting uninstall: google-ai-generativelanguage
#     Found existing installation: google-ai-generativelanguage 0.6.2
#     Uninstalling google-ai-generativelanguage-0.6.2:
#       Successfully uninstalled google-ai-generativelanguage-0.6.2
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.1.15
#     Uninstalling langchain-0.1.15:
#       Successfully uninstalled langchain-0.1.15
#   Attempting uninstall: google-generativeai
#     Found existing installation: google-generativeai 0.5.2
#     Uninstalling google-generativeai-0.5.2:
#       Successfully uninstalled google-generativeai-0.5.2
#   Attempting uninstall: langchain-google-genai
#     Found existing installation: langchain-google-genai 1.0.3
#     Uninstalling langchain-google-genai-1.0.3:
#       Successfully uninstalled langchain-google-genai-1.0.3
#   Attempting uninstall: scrapegraphai
#     Found existing installation: scrapegraphai 0.10.0
#     Uninstalling scrapegraphai-0.10.0:
#       Successfully uninstalled scrapegraphai-0.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# mergekit 0.0.4.1 requires tqdm==4.66.2, but you have tqdm 4.66.3 which is incompatible.
# Successfully installed google-ai-generativelanguage-0.4.0 google-generativeai-0.4.1 graphviz-0.20.1 html2text-2020.1.16 langchain-0.1.14 langchain-google-genai-1.0.1 langchain-openai-0.1.1 pandas-2.0.3 scrapegraphai-0.9.0b7 tiktoken-0.5.2 tqdm-4.66.3

# %%
# !playwright install
# Out:
# Downloading Chromium 124.0.6367.29 (playwright build v1112) from https://playwright.azureedge.net/builds/chromium/1112/chromium-mac-arm64.zip
# 133.5 MiB [                    ] 0% 0.0s133.5 MiB [                    ] 0% 152.5s133.5 MiB [                    ] 0% 88.2s133.5 MiB [                    ] 0% 92.3s133.5 MiB [                    ] 0% 94.9s133.5 MiB [                    ] 0% 95.4s133.5 MiB [                    ] 0% 97.4s133.5 MiB [                    ] 0% 97.0s133.5 MiB [                    ] 0% 111.9s133.5 MiB [                    ] 0% 101.7s133.5 MiB [                    ] 0% 109.1s133.5 MiB [                    ] 0% 109.9s133.5 MiB [                    ] 0% 114.6s133.5 MiB [                    ] 0% 117.8s133.5 MiB [                    ] 0% 121.7s133.5 MiB [                    ] 0% 123.0s133.5 MiB [                    ] 0% 124.8s133.5 MiB [                    ] 0% 127.0s133.5 MiB [                    ] 0% 133.7s133.5 MiB [                    ] 0% 133.8s133.5 MiB [                    ] 0% 136.8s133.5 MiB [                    ] 0% 145.2s133.5 MiB [                    ] 0% 151.0s133.5 MiB [                    ] 0% 155.8s133.5 MiB [                    ] 0% 160.2s133.5 MiB [                    ] 0% 164.6s133.5 MiB [                    ] 0% 167.3s133.5 MiB [                    ] 0% 169.8s133.5 MiB [                    ] 0% 172.5s133.5 MiB [                    ] 0% 173.5s133.5 MiB [                    ] 0% 174.7s133.5 MiB [                    ] 0% 175.7s133.5 MiB [                    ] 0% 175.9s133.5 MiB [                
# Webkit 17.4 (playwright build v1992) downloaded to /Users/1littlecoder/Library/Caches/ms-playwright/webkit-1992

# %%
#!ollama pull mistral

# %%
#!ollama pull nomic-embed-text

# %%
from scrapegraphai.graphs import SmartScraperGraph

graph_config = {
    "llm": {
        "model": "ollama/mistral",
        "temperature": 0,
        "format": "json",  # Ollama needs the format to be specified explicitly
        "base_url": "http://localhost:11434",  # set Ollama URL
    },
    "embeddings": {
        "model": "ollama/nomic-embed-text",
        "base_url": "http://localhost:11434",  # set Ollama URL
    }
}

# %%
smart_scraper_graph = SmartScraperGraph(
    prompt="List me top latest article",
    # also accepts a string with the already downloaded HTML code
    source="https://www.espncricinfo.com/",
    config=graph_config
)

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
result = smart_scraper_graph.run()
print(result)
# Out:
# {'version': '1.1', 'title': "IPL 2024: McClenaghan on Rahul's need for confidence, Sangakkara backs Samson for T20 WC | ESPNcricinfo.com", 'description': "Get the latest updates from IPL 2024 as McClenaghan talks about Rahul's need for confidence and Sangakkara backs Samson for the T20 World Cup.", 'image': 'https://a.espncdn.com/combiner/i/info-graphics/cricket/2024/05/10/1368798_1368798_1368798_1368798_1368798.jpg?width=1200&height=630', 'datePublished': '2024-05-10T13:30:00Z', 'dateModified': '2024-05-10T13:30:00Z', 'author': {'name': 'ESPNcricinfo Staff'}, 'publisher': {'name': 'ESPNCricinfo.com', 'logo': {'url': 'https://a.espncdn.com/combiner/i/espn/logo-espncricinfo.png?width=300&height=150', 'width': 300, 'height': 150}, 'section': 'Cricket', 'contentType': 'video', 'duration': 'PT2M48S', 'thumbnailUrl': 'https://a.espncdn.com/combiner/i/info-graphics/cricket/2024/05/10/1368798_1368798_1368798_1368798_1368798.jpg?width=1200&height=630', 'embedHtml': '<iframe width="560" height="315" src="https://www.youtube.com/embed/-vZjKzJwWxk?rel=0&amp;showinfo=0" frameborder="0" allowfullscreen></iframe>', 'keywords': ['IPL 2024', 'Rahul', 'McClenaghan', 'confidence', 'Sangakkara', 'Samson', 'T20 World Cup'], 'categories': [{'term': 'Cricket'}], 'interactionCount': {'viewItemCount': 1, 'upvoteCount': 0, 'downvoteCount': 0, 'commentCount': 0}, 'source': {'name': 'YouTube', 'url': 'https://www.youtube.com/embed/-vZjKzJwWxk?rel=0&amp;showinfo=0'}}}

# %%
import pandas as pd
# Creating a DataFrame
df = pd.DataFrame(result['articles'])
df
# Out:
# /Users/1littlecoder/Library/Python/3.9/lib/python/site-packages/IPython/core/formatters.py:344: FutureWarning: RangeIndex.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   return method()
# Empty DataFrame
# Columns: []
# Index: []
